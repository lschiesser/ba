# %% [markdown]
# # TITLE PENDING
# ### Bachelor's thesis by Lukas Schießer

# %%
from rpy2.robjects.packages import importr
base = importr('base')
base._libPaths("C:/Users/lukas/Documents/R/win-library/4.0")
mice = importr('mice')
utils = importr('utils')

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy import stats

# %% [markdown]
# ### Preprocessing

# %%
pd.options.display.max_columns = None
os.getcwd()
os.chdir("C:/code/Uni/ba")
data = pd.read_excel('blood-exams/covid_study_v2.xlsx')

# %%
data.insert(0,'male',(data["GENDER"] == "M").astype('int64'))
data.insert(0,'female',(data["GENDER"] == "F").astype('int64'))
data.drop(columns="GENDER", inplace=True)
data['Lymphocytes'] = pd.to_numeric(data['Lymphocytes'], errors='coerce')
data.loc[data["AGE"] < 18, "AGE"] = np.NaN
data.head()
# Out:
#    female  male   AGE   WBC  Platelets  Neutrophils  Lymphocytes  Monocytes  \
# 0       0     1  56.0   2.9      128.0          1.9          0.8        0.2
# 1       0     1  56.0   3.5      151.0          2.1          0.9        0.4
# 2       0     1  72.0   4.6      206.0          NaN          NaN        NaN
# 3       0     1  72.0  16.5      316.0         14.0          1.2        0.3
# 4       0     1  77.0   4.9      198.0          NaN          NaN        NaN
#
#    Eosinophils  Basophils    CRP   AST   ALT   ALP   GGT    LDH  SWAB
# 0          0.0        0.0   29.0  36.0  18.0  43.0  21.0  257.0     1
# 1          0.0        0.0   16.5  25.0  14.0  50.0  17.0  207.0     1
# 2          NaN        NaN  193.7  31.0  22.0   NaN   NaN    NaN     1
# 3          0.0        0.0  318.7  96.0  33.0  80.0  42.0  651.0     1
# 4          NaN        NaN    NaN   NaN   NaN   NaN   NaN    NaN     1

# %%
data.describe()
# Out:
#            female        male         AGE         WBC   Platelets  \
# count  279.000000  279.000000  277.000000  277.000000  277.000000
# mean     0.326165    0.673835   61.776173    8.553069  226.532130
# std      0.469651    0.469651   17.815695    4.855353  101.174178
# min      0.000000    0.000000   18.000000    1.100000   20.000000
# 25%      0.000000    0.000000   49.000000    5.100000  163.000000
# 50%      0.000000    1.000000   64.000000    7.100000  205.000000
# 75%      1.000000    1.000000   76.000000   10.700000  271.000000
# max      1.000000    1.000000   98.000000   29.200000  620.000000
#
#        Neutrophils  Lymphocytes   Monocytes  Eosinophils   Basophils  \
# count   209.000000   208.000000  209.000000   209.000000  208.000000
# mean      6.200478     1.186538    0.605742     0.055024    0.014423
# std       4.172581     0.806442    0.410049     0.132237    0.039116
# min       0.500000     0.200000    0.000000     0.000000    0.000000
# ...

# %%
alpha = 0.05
for col in data.columns[2:-1]:
    # TODO: Perform a Shapiro-Wilk normality test
    stat, p = stats.shapiro(data[col].dropna())

    print('{}: stat={:0.3f}, p={:0.3f}; {}'.format(col, stat, p, 'Probably Normal' if p > alpha else 'Probably not Normal'))
# Out:
# AGE: stat=0.976, p=0.000; Probably not Normal
# WBC: stat=0.873, p=0.000; Probably not Normal
# Platelets: stat=0.930, p=0.000; Probably not Normal
# Neutrophils: stat=0.838, p=0.000; Probably not Normal
# Lymphocytes: stat=0.785, p=0.000; Probably not Normal
# Monocytes: stat=0.811, p=0.000; Probably not Normal
# Eosinophils: stat=0.457, p=0.000; Probably not Normal
# Basophils: stat=0.395, p=0.000; Probably not Normal
# CRP: stat=0.836, p=0.000; Probably not Normal
# AST: stat=0.556, p=0.000; Probably not Normal
# ALT: stat=0.629, p=0.000; Probably not Normal
# ALP: stat=0.420, p=0.000; Probably not Normal
# GGT: stat=0.500, p=0.000; Probably not Normal
# LDH: stat=0.877, p=0.000; Probably not Normal

# %%
fig, axes = plt.subplots(ncols=7, nrows=2, figsize=(20,6))
for x in range(2,16):
    i = x % 2
    j = x // 2 - 1
    sns.kdeplot(data[data.columns[x]], ax=axes[i,j], fill=True)
    axes[i,j].set_title(data.columns[x])
plt.tight_layout()

# %%
import matplotlib.patches as mpatches
blue_patch = mpatches.Patch(color='#4287f5', label='negative PCR')
red_patch = mpatches.Patch(color='#f03c45', label='positive PCR')
fig, axes = plt.subplots(ncols=7, nrows=2, figsize=(20,6))
for x in range(2,16):
    i = x % 2
    j = x // 2 - 1
    sns.kdeplot(data[data["SWAB"] == 0][data.columns[x]], ax=axes[i,j], color="blue", fill=True)
    sns.kdeplot(data[data["SWAB"] == 1][data.columns[x]], ax=axes[i,j], color="red", fill=True)
    axes[i,j].set_title(data.columns[x])
plt.tight_layout()
plt.legend(handles=[blue_patch, red_patch], loc="lower center",bbox_to_anchor=(-4.5,-0.6), fontsize="large")

# %% [markdown]
# As you can see, most of the blood values do not follow a standard normal distribution. This can impact the imputation process negatively since most implementations of MICE assume MAR (missing at random) and normality regarding the variables.

# %%
data.skew(axis=0, skipna=True)
# Out:
# female         0.745619
# male          -0.745619
# AGE           -0.364711
# WBC            1.465149
# Platelets      1.117437
# Neutrophils    1.856380
# Lymphocytes    2.844919
# Monocytes      2.428393
# Eosinophils    5.129964
# Basophils      3.233118
# CRP            1.474657
# AST            4.610819
# ALT            3.361072
# ALP            5.893664
# GGT            3.977782
# LDH            1.556878
# SWAB          -0.561202
# dtype: float64

# %% [markdown]
# ### Model preparation

# %%
# %%capture
s = []
import rpy2.robjects as ro
from rpy2.robjects.conversion import localconverter
from rpy2.robjects import pandas2ri
with localconverter(ro.default_converter + pandas2ri.converter):
    dm = mice.mice(X, m=5, maxit=20, seed=500);
    completed = mice.complete_mids(dm,1)

# %%
import matplotlib.patches as mpatches
blue_patch = mpatches.Patch(color='#4287f5', label='original')
red_patch = mpatches.Patch(color='#f03c45', label='completed')
fig, axes = plt.subplots(ncols=7, nrows=2, figsize=(20,6))
for x in range(2,16):
    i = x % 2
    j = x // 2 - 1
    sns.kdeplot(data[data.columns[x]], ax=axes[i,j], color="blue",fill=True)
    sns.kdeplot(completed[completed.columns[x]], ax=axes[i,j], color="red", fill=True)
    axes[i,j].set_title(completed.columns[x])
plt.legend(handles=[blue_patch, red_patch])
plt.tight_layout()

# %% [markdown]
# Applying MICE only to a small fraction of the data set (e.g., when using MCIE to only impute test set which has only up to 56 samples) we get very bad imputations as shown by the plots below. The distribution of the data is not sustained as it is when applying MICE to the whole data set. Therefore, I should apply MICE to the whole data set but during the nested cross validation process, so that I have a MICE model for each cross validation step/loop/split instead of defining two MICE models to impute the training and testing set individually.

# %%
# import all necessary tools
from sklearn.model_selection import KFold, GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
# import MissingIndicator to save missing value pattern for comparisons
from sklearn.impute import MissingIndicator
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
# imported confusion_matrix because it return TP, TN, FP, FN which are required to compute sensitivity and positive predictive value
import rpy2.robjects as ro
from rpy2.robjects.conversion import localconverter
from rpy2.robjects import pandas2ri
from IPython.utils import io

# %%
X, y = data[data.columns[:-1]], data["SWAB"]
# save missing value pattern once to compare observed and imputed values for each variable and whole data set later

# %%
def calculate_eval_metrics(model, y_pred, y_true, x_test):
    """
    Function to calculate the evaluation metrics of a model
    
    Parameters
    ----------
    model: sklearn Object
        model that should be evaluated
    y_pred: list
        list of predictions of the model
    y_true: list
        list of (true) target values for prediction
    x_test: pd.DataFrame
        pandas DataFrame with 
    
    Returns
    -------
    acc: float
        accuracy for model
    balanced_acc: float
        balanced accuracy for model
    sensitivity: float
        sensitivity for model
    ppv: float
        positive predictive value for model
    auc: float
        area under the curve
    """
    acc = accuracy_score(y_true, y_pred)
    balanced_acc = balanced_accuracy_score(y_true, y_pred)
    # sensitivity = TP/TP+FN
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp/(tp + fn)
    # specificity = TN/TN+FP
    specificity = tn/(tn+fp)
    # PPV = TP/TP+FP
    ppv = tp/(tp + fp)
    # roc auc
    scores = model.predict_proba(x_test)
    # roc_auc_score return area under the curve metric
    auc = roc_auc_score(y_true, scores[:,1])
    return acc, balanced_acc, sensitivity, specificity, ppv, auc

# %%
def save_eval_metrics(metrics, storage, fold,i, count, model):
    """
    Saves evaluation metrics to a specified variable
    
    Parameters
    ----------
    metrics: tuple
        all evaluation metrics calculated by calculate_eval_metrics
    storage: pd.DataFrame
        dataframe where the metrics should be stroed in
    fold: int
        current fold of CV
    model: string
        type of model
        
    Returns
    -------
    pd.DataFrame
        updated storage dataframe 
    """
    acc, balanced_acc, sensitivity, specificity, ppv, auc = metrics
    storage = storage.append({
        "Fold": fold,
        "Imputed Set": i,
        "Model": model,
        "Model Count": count,
        "acc": acc,
        "b_acc": balanced_acc,
        "sensitivity": sensitivity,
        "specificity": specificity,
        "ppv": ppv,
        "auc": auc
    }, ignore_index=True)
    return storage

# %%
def make_eval_storage():
    """
    Prepares skeleton structure for evaluation storage DataFrame
        
    Returns
    -------
    pandas DataFrame
        empty skeleton DataFrame with header names
    """
    return pd.DataFrame(columns=["Fold", "Imputed Set", "Model", "Model Count", "acc", "b_acc", "sensitivity", "specificity", "ppv", "auc"])

# %%
import warnings
from progress.bar import Bar
from ipywidgets import IntProgress
from IPython.display import display
warnings.filterwarnings('ignore')
N_SPLITS = 5
N_IMP = 5
storage = make_eval_storage()
imputed_data = []
rf_models = []
lr_models = []
# prepare 5-fold nested cross validation by defining outer loop of nested cv
cv_outer = KFold(n_splits=N_SPLITS, shuffle=True, random_state=1)
# outer loop of CV
fold = 0
counter = 0
bar = Bar(message='Prog', max=25, check_tty=False, hide_cursor=False)
for train_index, test_index in cv_outer.split(X, y):
    with localconverter(ro.default_converter + pandas2ri.converter):
        with io.capture_output() as captured:
            dm = mice.mice(X, m=N_IMP, maxit=20, seed=500);
        for i in range(1, N_IMP+1):
            completed = mice.complete_mids(dm,i)
            imputed_data.append(completed)
            X_train, X_test = completed.iloc[train_index], completed.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            # define inner loop of nested cross validation
            cv_inner = KFold(n_splits=N_SPLITS, shuffle=True, random_state=1)
            # instantiate model for hyperparameter search by means of GridSearch
            rf = RandomForestClassifier(random_state=1)
            # define the search space over which GridSearch should search
            rf_space = {
                'n_estimators': [10, 100, 500],
                'max_features': [4, 8, 12, 16],
                'criterion': ["gini", "entropy"]
            }
            # define GridSearch for nested cv
            rf_search = GridSearchCV(rf, rf_space, cv=cv_inner, refit=True, scoring="accuracy")
            rf_result = rf_search.fit(X_train, y_train)
            # get the best performing model fit on the whole training set
            rf_best_model = rf_result.best_estimator_
            rf_yhat = rf_best_model.predict(X_test)
            # same for logistic regression
            lr_space = {
                'C': np.logspace(-3, 3, 7),
                'penalty': ['l1', 'l2'],
                'solver': ['liblinear', 'saga'],
                'max_iter': [200, 300, 400, 500]
            }
            lr = LogisticRegression(random_state=1)
            lr_search = GridSearchCV(lr, lr_space, cv=cv_inner, refit=True, scoring="accuracy")
            lr_result = lr_search.fit(X_train, y_train)
            lr_best_model =  lr_result.best_estimator_
            lr_yhat = lr_best_model.predict(X_test)
            # evaluate the models and save in storage
            storage = save_eval_metrics(calculate_eval_metrics(rf_best_model, rf_yhat, y_test, X_test), storage, fold, i, counter, "rf")
            storage = save_eval_metrics(calculate_eval_metrics(lr_best_model, lr_yhat, y_test, X_test), storage, fold, i, counter, "lr")
            # add models to list for later inspection
            rf_models.append(rf_best_model)
            lr_models.append(lr_best_model)
            # add imputed data to list for later inspection
            imputed_data.append(completed)
            counter += 1
            # print(fold, i)
            bar.next()
    fold += 1
bar.finish()
# Out:
# Prog |################################| 25/25

# %% [markdown]
# #### Export metrics to use in new Notebook for visualization
# (Notebooks will be merged eventually for final version; export will be kept)

# %%
storage.to_csv(path_or_buf="notebooks/metrics/eval_storage.csv", index=False)

# %%
with open("notebooks/metrics/rf.txt", "w") as rf_file, open("notebooks/metrics/lr.txt", "w") as lr_file:
    for i, j, idx in zip(rf_models, lr_models, range(len(rf_models))):
        rf_file.write("{:d}: {} \n".format(idx, str(i.get_params())))
        lr_file.write("{:d}: {} \n".format(idx, str(j.get_params())))

# %% [markdown]
# ### Visualization of metrics gathered during CV and model selection

# %%
def print_summary(data, metric):
    """
    Prints a summary for a metric in the DataFrame for each classifier
    Paramters:
    ----------
    data: pd.DataFrame
        dataframe with all evaluation metrics
    metric: string
        string identifier of metric
    """
    dash = '-' * 90
    print(metric)
    print(dash)
    print('{:<10s}{:<13s}{:<13s}{:<13s}{:<13s}{:<13s}{:<13s}'.format("Model","Fold 1","Fold 2","Fold 3", "Fold 4", "Fold 5", "Combined"))
    print(dash)
    for model in ['rf', 'lr']:
        tmp = []
        for i in range(5):
            tmp.append(data.loc[(data["Fold"] == i) & (data["Model"]==model)][metric].mean())
            tmp.append(data.loc[(data["Fold"] == i) & (data["Model"]==model)][metric].std())
        tmp.append(data[data["Model"] == model][metric].mean())
        tmp.append(data[data["Model"] == model][metric].std())
        print('{:<10s}{:<3.2f} ({:<3.2f})  {:<3.2f} ({:<3.2f})  {:<3.2f} ({:<3.2f})  {:<3.2f} ({:<3.2f})  {:<3.2f} ({:<3.2f})  {:<3.2f} ({:<3.2f})  '.format(model,*tmp))
    print("\n")

# %%
cv_cols = ['acc', 'b_acc', 'sensitivity', 'specificity', 'ppv', 'auc']
for x in cv_cols:
    print_summary(storage, x)
# Out:
# acc
# ------------------------------------------------------------------------------------------
# Model     Fold 1       Fold 2       Fold 3       Fold 4       Fold 5       Combined
# ------------------------------------------------------------------------------------------
# rf        0.72 (0.01)  0.84 (0.03)  0.81 (0.03)  0.75 (0.03)  0.77 (0.03)  0.78 (0.05)
# lr        0.71 (0.03)  0.81 (0.02)  0.74 (0.03)  0.70 (0.06)  0.73 (0.04)  0.74 (0.05)
#
#
# b_acc
# ------------------------------------------------------------------------------------------
# Model     Fold 1       Fold 2       Fold 3       Fold 4       Fold 5       Combined
# ------------------------------------------------------------------------------------------
# rf        0.69 (0.01)  0.81 (0.04)  0.79 (0.03)  0.73 (0.02)  0.71 (0.04)  0.75 (0.05)
# lr        0.67 (0.02)  0.78 (0.03)  0.72 (0.03)  0.68 (0.06)  0.67 (0.04)  0.70 (0.06)
#
#
# sensitivity
# ...

# %%
def find_best_model(data, model):
    """
    Searches for the maximum for every evaluation metric in the dataframe for one model
    Parameters:
    -----------
    data: pd.DataFrame
        DataFrame with all evaluation metrics
    model: String
        string identifier for model
    Returns:
    --------
    int
        index of row where most metrics had a maximum (is chosen )
    """
    cv_cols = ['acc', 'b_acc', 'sensitivity', 'specificity', 'ppv', 'auc']
    ids = []
    print(model)
    for x in cv_cols:
        max_id = data[data['Model'] == model][x].idxmax()
        max_val = data.loc[max_id, x]
        ids.append(max_id)
        print("{:s}: id {:d} with {:.2f} (Model Count: {:d})".format(x, max_id, max_val, data.loc[max_id, "Model Count"]))
    print("\n")
    return max(set(ids), key = ids.count)

# %%
idx = find_best_model(storage, 'rf')
print(storage.iloc[idx].to_frame().T)
best_rf_idx = storage.loc[idx, "Model Count"]
idx = find_best_model(storage, 'lr')
print(storage.iloc[idx].to_frame().T)
best_lr_idx = storage.loc[idx, "Model Count"]
# Out:
# rf
# acc: id 10 with 0.88 (Model Count: 5)
# b_acc: id 10 with 0.86 (Model Count: 5)
# sensitivity: id 22 with 0.94 (Model Count: 11)
# specificity: id 10 with 0.81 (Model Count: 5)
# ppv: id 10 with 0.92 (Model Count: 5)
# auc: id 14 with 0.85 (Model Count: 7)
#
#
# Fold                  1
# Imputed Set           1
# Model                rf
# Model Count           5
# acc               0.875
# b_acc           0.85625
# sensitivity         0.9
# specificity      0.8125
# ppv            0.923077
# auc            0.847656
# Name: 10, dtype: object
# lr
# acc: id 13 with 0.84 (Model Count: 6)
# b_acc: id 13 with 0.83 (Model Count: 6)
# sensitivity: id 41 with 0.97 (Model Count: 20)
# specificity: id 13 with 0.81 (Model Count: 6)
# ppv: id 13 with 0.92 (Model Count: 6)
# auc: id 13 with 0.87 (Model Count: 6)
#
#
# Fold                  1
# Imputed Set           2
# Model                lr
# Model Count           6
# acc            0.839286
# b_acc           0.83125
# ...

# %%
rf_models[best_rf_idx].get_params()
# Out:
# RandomForestClassifier(max_features=4, n_estimators=500, random_state=1)

# %%
lr_models[best_lr_idx].get_params()
# Out:
# LogisticRegression(C=10.0, max_iter=200, random_state=1, solver='liblinear')

# %% [markdown]
# ## Future validation procedure
# Here Decision Tree is also built

# %%
def make_val_storage():
    """
    Prepares skeleton structure for validation storage DataFrame
        
    Returns
    -------
    pandas DataFrame
        empty skeleton DataFrame with header names
    """
    return pd.DataFrame(columns=["Model", "acc", "b_acc", "sensitivity", "specificity", "ppv", "fpr" , "tpr", "auc", "precision", "recall", "a_precision"])

# %%
def calculate_val_metrics(model, y_pred, y_true, x_test):
    """
    Function to calculate the validation metrics of a model
    
    Parameters
    ----------
    model: sklearn Object
        model that should be validated
    y_pred: list
        list of predictions of the model
    y_true: list
        list of (true) target values for prediction
    x_test: pd.DataFrame
        pandas DataFrame with 
    
    Returns
    -------
    acc: float
        accuracy for model
    balanced_acc: float
        balanced accuracy for model
    sensitivity: float
        sensitivity for model
    ppv: float
        positive predictive value for model
    auc: float
        area under the curve
    fpr: list
        false positive rate for model
    tpr: list
        true postive rate for model
    precision: list
        precision rate for model
    recall: list
        recall rate for model
    """
    acc = accuracy_score(y_true, y_pred)
    balanced_acc = balanced_accuracy_score(y_true, y_pred)
    # sensitivity = TP/TP+FN
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp/(tp + fn)
    # specificity = TN/TN+FP
    specificity = tn/(tn+fp)
    # PPV = TP/TP+FP
    ppv = tp/(tp + fp)
    # roc auc
    scores = model.predict_proba(x_test)
    # roc_auc_score return area under the curve metric
    auc = roc_auc_score(y_true, scores[:,1])
    # roc_curve returns false positive rate (fpr), true positive rate (tpr) and thresholds (not needed for visualization)
    fpr, tpr, _ = roc_curve(y_true, scores[:,1])
    precision, recall, _ = precision_recall_curve(y_true, scores[:,1])
    avg_prec = average_precision_score(y_true, scores[:, 1])
    return acc, balanced_acc, sensitivity, specificity, ppv, auc, fpr, tpr, precision, recall, avg_prec

# %%
def save_val_metrics(metrics, storage, model):
    """
    Saves validation metrics to a specified variable
    
    Parameters
    ----------
    metrics: tuple
        all validation metrics calculated by calculate_eval_metrics
    storage: pd.DataFrame
        dataframe where the metrics should be stored in
    model: string
        type of model
        
    Returns
    -------
    pd.DataFrame
        updated storage dataframe 
    """
    acc, balanced_acc, sensitivity, specificity, ppv, auc, fpr, tpr, precision, recall, avg_precision = metrics
    storage = storage.append({
        "Model": model,
        "acc": acc,
        "b_acc": balanced_acc,
        "sensitivity": sensitivity,
        "specificity": specificity,
        "ppv": ppv,
        "fpr": fpr,
        "tpr": tpr,
        "auc": auc,
        "precision": precision,
        "recall": recall,
        "a_precision": avg_precision
        
    }, ignore_index=True)
    return storage

# %%
with localconverter(ro.default_converter + pandas2ri.converter):
    with io.capture_output() as captured:
        dm = mice.mice(X, m=N_IMP, maxit=20, seed=500);
    completed_X = mice.complete_mids(dm,1)
    X_train, X_validate, y_train, y_validate = train_test_split(completed_X, y, test_size=0.20, random_state=1)

# %%
# retrain models and validate them
val_storage = make_val_storage()
# intialize models
best_rf = rf_models[best_rf_idx]
best_lr = lr_models[best_lr_idx]
dt = DecisionTreeClassifier(random_state=0)
# train models
best_rf = best_rf.fit(X_train, y_train)
best_lr = best_lr.fit(X_train, y_train)
dt = dt.fit(X_train, y_train)
best_rf_yhat = best_rf.predict(X_validate)
best_lr_yhat = best_lr.predict(X_validate)
dt_yhat = dt.predict(X_validate)
val_storage = save_val_metrics(calculate_val_metrics(best_rf, best_rf_yhat, y_validate, X_validate), val_storage, "rf")
val_storage = save_val_metrics(calculate_val_metrics(best_lr, best_lr_yhat, y_validate, X_validate), val_storage, "lr")
val_storage = save_val_metrics(calculate_val_metrics(dt, dt_yhat, y_validate, X_validate), val_storage, "dt")

# %% [markdown]
# ### Visualization of metrics gathered during Model valdiation

# %%
val_storage.to_csv(path_or_buf="notebooks/metrics/val_storage.csv", index=False)

# %%
# feature importance
names = {"rf": "Random Forest", "lr": "Logistic Regression", "dt": "Decision Tree"}
# ROC Curve and Precision/recall curve
fig, ax = plt.subplots()
for index, row in val_storage.iterrows():
    plt.plot(row.fpr, row.tpr, lw=2, alpha=.8, label=names[row["Model"]])
plt.title("ROC Curve")
plt.plot([0,1],[0,1], transform=ax.transAxes, color="lightgrey", linestyle="--")
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.legend(loc="lower right")
fig.savefig("notebooks/figures/roc.jpg")
fig.show()

# %%
plt.figure()
for index, row in val_storage.iterrows():
    plt.plot(row.recall, row.precision, lw=2, alpha=.8, label=names[row["Model"]])
plt.title("Precision-Recall Curve")
plt.xlim(0, 1)
plt.ylim(0, 1)
value_counts = y.value_counts()
plt.axhline(value_counts[1]/y.count(), color="lightgrey", linestyle="--")
plt.ylabel("Precision")
plt.xlabel("Recall")
plt.legend(loc="lower left")
plt.savefig("notebooks/figures/prc.jpg")
plt.show()

# %%
rf_importance = best_rf.feature_importances_
rf_indices = np.argsort(rf_importance)

rf_names = [X.columns[i] for i in rf_indices]
plt.figure()

# Create plot title
plt.title("Random Forest: Feature Importance")

# Add bars
plt.barh(range(X.shape[1]), rf_importance[rf_indices])

# Add feature names as x-axis labels
plt.yticks(range(X.shape[1]), rf_names)
plt.tight_layout()
plt.savefig("notebooks/figures/rf_importance.jpg")
# Show plot
plt.show()


dt_importance = dt.feature_importances_
dt_indices = np.argsort(dt_importance)

dt_names = [X.columns[i] for i in dt_indices]
plt.figure()

# Create plot title
plt.title("Decision Tree: Feature Importance")

# Add bars
plt.barh(range(X.shape[1]), dt_importance[dt_indices])

# Add feature names as x-axis labels
plt.yticks(range(X.shape[1]), dt_names)
plt.tight_layout()
plt.savefig("notebooks/figures/dt_importance.jpg")
# Show plot
plt.show()
lr_coef = best_lr.coef_[0]
lr_indices = np.argsort(lr_coef)

lr_names = [X.columns[i] for i in lr_indices]
plt.figure()

# Create plot title
plt.title("Logistic Regression: Feature Importance")

# Add bars
plt.barh(range(X.shape[1]), lr_coef[lr_indices])

# Add feature names as x-axis labels
plt.yticks(range(X.shape[1]), lr_names)
plt.tight_layout()
plt.savefig("notebooks/figures/lr_importance.jpg")
# Show plot
plt.show()

# %% [markdown]
# #### Decision tree visualization

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt, 
                   feature_names=data.columns,
                   class_names=["0", "1"],
                   filled=True)
fig.savefig("notebooks/figures/dt.jpg")

# %% [markdown]
# # Store eval and validation measures as latex tables

# %%
# store pandas dataframes as latex tables to inlcude in appendix
storage.sort_values(by=["Model", "Model Count"]).to_latex(buf="notebooks/metrics/eval_storage.tex", float_format="%.3f", index=False)
# save validation storage without tpr, fpr, precision and recall since they are lists and already included in csv export and PRC and ROC plots

val_storage.drop(columns=["tpr", "fpr", "precision", "recall"]).to_latex(buf="notebooks/metrics/val_storage.tex", float_format="%.3f", index=False)

# %%
def describe_imputed(original, imputed_sets):
    """
    Creates a dataframe with mean and standard deviations (std) for the original and imputed data
    """
    # initialize dataframe
    header = ["Dataset"]
    for column in original.columns[2:]:
        for metric in ["mean", "std"]:
            header.append((column, metric))
    describe_df = pd.DataFrame(columns=header)
    # compute mean and std for original dataframe
    original = original.describe().iloc[1:3]
    tmp = ["original"]
    for column in original.columns[2:]:
        for metric in ["mean", "std"]:
            tmp.append(original.loc[metric, column])
    describe_df = describe_df.append(pd.Series(tmp, index=header), ignore_index=True)
    # compute mean and std for every imputed dataframe
    for df, idx in zip(imputed_sets, range(len(imputed_sets))):
        t = df.describe().iloc[1:3]
        tmp = [int(idx+1)]
        for column in t.columns[2:]:
            for metric in ["mean", "std"]:
                tmp.append(t.loc[metric, column])
        describe_df = describe_df.append(pd.Series(tmp, index=header), ignore_index=True)
    # reorder columns for better visualization
    describe_df.set_index("Dataset", inplace=True)
    describe_df.columns = pd.MultiIndex.from_tuples(describe_df.columns)
    return describe_df

# %%
df = describe_imputed(X, imputed_data)
df.to_latex(buf="notebooks/metrics/imputed.tex", float_format="%.3f", index=True)
