# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pd.options.display.max_columns = None
os.getcwd()
os.chdir("C:/code/Uni/ba/blood-exams")
data = pd.read_excel('covid_study_v2.xlsx')
data.head()
# Out:
#   GENDER  AGE   WBC  Platelets  Neutrophils Lymphocytes  Monocytes  \
# 0      M   56   2.9      128.0          1.9         0.8        0.2
# 1      M   56   3.5      151.0          2.1         0.9        0.4
# 2      M   72   4.6      206.0          NaN         NaN        NaN
# 3      M   72  16.5      316.0         14.0         1.2        0.3
# 4      M   77   4.9      198.0          NaN         NaN        NaN
#
#    Eosinophils  Basophils    CRP   AST   ALT   ALP   GGT    LDH  SWAB
# 0          0.0        0.0   29.0  36.0  18.0  43.0  21.0  257.0     1
# 1          0.0        0.0   16.5  25.0  14.0  50.0  17.0  207.0     1
# 2          NaN        NaN  193.7  31.0  22.0   NaN   NaN    NaN     1
# 3          0.0        0.0  318.7  96.0  33.0  80.0  42.0  651.0     1
# 4          NaN        NaN    NaN   NaN   NaN   NaN   NaN    NaN     1

# %%
for val in data.SWAB.unique():
    anteil = (data[data['SWAB'] == val].shape[0]/data.shape[0])*100
    print(f"SWAB = {val} in %: {anteil :04.2f}")
# Out:
# SWAB = 1 in %: 63.44
# SWAB = 0 in %: 36.56

# %%
summary = data.describe()
summary = summary.append(pd.Series((data.isnull().sum(axis=0)/data.shape[0])*100, name="NaNs in %"))
for val in data.SWAB.unique():
    total = data[data['SWAB'] == val].shape[0]
    summary = summary.append(pd.Series((data[data['SWAB'] == val].isnull().sum(axis=0)/total)*100,name=f"NaNs for SWAB = {val} in %"))

# %%
print("Anzahl an Datensätzen: ", data.shape[0])
summary
# Out:
# Anzahl an Datensätzen:  279
#                                AGE         WBC   Platelets  Neutrophils  \
# count                   279.000000  277.000000  277.000000   209.000000
# mean                     61.336918    8.553069  226.532130     6.200478
# std                      18.491523    4.855353  101.174178     4.172581
# min                       0.000000    1.100000   20.000000     0.500000
# 25%                      49.000000    5.100000  163.000000     3.500000
# 50%                      64.000000    7.100000  205.000000     5.100000
# 75%                      76.000000   10.700000  271.000000     7.500000
# max                      98.000000   29.200000  620.000000    26.400000
# NaNs in %                 0.000000    0.716846    0.716846    25.089606
# NaNs for SWAB = 1 in %    0.000000    1.129944    1.129944    16.949153
# NaNs for SWAB = 0 in %    0.000000    0.000000    0.000000    39.215686
#
#                          Monocytes  Eosinophils   Basophils         CRP  \
# count                   209.000000   209.000000  208.000000  273.000000
# mean                      0.605742     0.055024    0.014423   90.889011
# std                       0.410049     0.132237    0.039116   94.421406
# min                       0.000000     0.000000    0.000000    0.100000
# 25%                       0.400000     0.000000    0.000000   21.400000
# 50%                       0.500000     0.000000    0.000000   54.200000
# 75%                       0.700000     0.100000    0.000000  129.100000
# max                       3.200000     1.300000    0.300000  478.000000
# NaNs in %                25.089606    25.089606   25.448029    2.150538
# NaNs for SWAB = 1 in %   16.949153    16.949153   17.514124    2.824859
# NaNs for SWAB = 0 in %   39.215686    39.215686   39.215686    0.980392
#
#                                AST         ALT         ALP         GGT  \
# count                   277.000000  266.000000  131.000000  136.000000
# mean                     54.202166   44.917293   89.893130   82.477941
# std                      57.612797   45.503232   89.089864  132.702506
# min                      11.000000    9.000000   34.000000   10.000000
# 25%                      27.000000   21.000000   57.500000   23.750000
# 50%                      36.000000   31.000000   71.000000   41.000000
# 75%                      60.000000   46.000000   90.000000   83.000000
# max                     550.000000  335.000000  838.000000  839.000000
# NaNs in %                 0.716846    4.659498   53.046595   51.254480
# NaNs for SWAB = 1 in %    1.129944    7.344633   49.717514   51.412429
# NaNs for SWAB = 0 in %    0.000000    0.000000   58.823529   50.980392
#
#                                 LDH        SWAB  GENDER  Lymphocytes
# count                    194.000000  279.000000     NaN          NaN
# mean                     380.448454    0.634409     NaN          NaN
# std                      193.983520    0.482461     NaN          NaN
# min                       98.000000    0.000000     NaN          NaN
# 25%                      243.250000    0.000000     NaN          NaN
# 50%                      328.000000    1.000000     NaN          NaN
# 75%                      454.500000    1.000000     NaN          NaN
# max                     1195.000000    1.000000     NaN          NaN
# NaNs in %                 30.465950    0.000000     0.0    25.089606
# NaNs for SWAB = 1 in %    25.988701    0.000000     0.0    16.949153
# NaNs for SWAB = 0 in %    38.235294    0.000000     0.0    39.215686

# %%
corr = data.corr()
f, ax = plt.subplots(figsize=(9, 9))

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
fig, axes = plt.subplots(len(data.columns) // 6, 6, figsize=(15, 10))
i = 2
for triaxis in axes:
    for axis in triaxis:
        col = data.columns[i]
        try:
            data[col] = pd.to_numeric(data[col])
        except:
            print(col)
        try:
            data.hist(column = col, bins = 100, ax=axis)
        except:
            axis.hist([])
            axis.set_title(col)
        i = i+1
# Out:
# Lymphocytes
